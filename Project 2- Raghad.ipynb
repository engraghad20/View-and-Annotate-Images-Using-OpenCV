# %%
import cv2

# %%
image = cv2.imread(r"C:\Users\ragad\Downloads\Rose.jpeg")

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
cv2.imshow("Hash-Plus",image)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("Hash-Plus",image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.putText(image , "Hash-Plus" , (0,100) , cv2.FONT_HERSHEY_DUPLEX , 3, (255 ,0,0), 3)

# %%
cv2.imshow("Hash Plus",image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.rectangle(image, (570,40), (580,110), (255,79,77),5)
image = cv2.rectangle(image, (610,40), (620,70), (188,226,51),5) 
image = cv2.rectangle(image, (600,50), (630,60), (188,226,51),5) 
image = cv2.rectangle(image, (610,70), (620,110), (239,108,189),5) 
image = cv2.rectangle(image, (560,90), (630,100), (255,79,77),5)
image = cv2.rectangle(image, (560,50), (590,60), (239,108,189),5)

# %%
cv2.imshow("Hash Plus",image)
cv2.waitKey(0)
